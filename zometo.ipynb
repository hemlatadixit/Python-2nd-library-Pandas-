# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("zomato.csv")    #,#encoding="latin-1")
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df['Country Code'].unique()
# Out:
# array([162,  30, 216,  14,  37, 184, 214,   1,  94, 148, 215, 166, 189,
#        191, 208], dtype=int64)

# %%
df1=pd.read_excel("Zomato_Country-Code.xlsx")   
df1
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df1.shape
# Out:
# (15, 2)

# %%
df1['Country Code'].unique()
# Out:
# array([  1,  14,  30,  37,  94, 148, 162, 166, 184, 189, 191, 208, 214,
#        215, 216], dtype=int64)

# %%
df1.columns
# Out:
# Index(['Country Code', 'Country'], dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  15 non-null     int64
#  1   Country       15 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 368.0+ bytes

# %% [markdown]
# ## IN DATA ANALYSIS WHAT ALL THINKS WE DO
# ### 1.Missing values
# ### 2:Explore about numerical data
# ### 3:Explore about catagorical data
# ### 4:Finding relationshiop btw features

# %% [markdown]
# ### checking missing values

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df2=pd.merge(df,df1,on='Country Code',how='left')
df2
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
''' checking tha shape of data'''
df2.shape
# Out:
# (9551, 22)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df2.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
df2['Cuisines'].fillna(df2['Cuisines'].mode()[0],inplace=True)

# %%
df2['Cuisines']
# Out:
# 0             French, Japanese, Desserts
# 1                               Japanese
# 2       Seafood, Asian, Filipino, Indian
# 3                        Japanese, Sushi
# 4                       Japanese, Korean
#                       ...
# 9546                             Turkish
# 9547     World Cuisine, Patisserie, Cafe
# 9548              Italian, World Cuisine
# 9549                     Restaurant Cafe
# 9550                                Cafe
# Name: Cuisines, Length: 9551, dtype: object

# %%
df2.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9546    False
# 9547    False
# 9548    False
# 9549    False
# 9550    False
# Length: 9551, dtype: bool

# %% [markdown]
# ## EDA

# %% [markdown]
# ### frst we check how many zometo restarurants in each country

# %%
df2["Country"].value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
sns.countplot(x='Country',data=df2);
plt.xticks(rotation=90);

# %% [markdown]
# ### from  above data we can take country india and do analysis on rastaruants  Only in india and find best rastaruant.

# %%
final_df=df2[df2["Country"]=="India"]
final_df.head()
# Out:
#      Restaurant ID                        Restaurant Name  Country Code  City  \
# 624        3400025                             Jahanpanah             1  Agra
# 625        3400341                    Rangrezz Restaurant             1  Agra
# 626        3400005                Time2Eat - Mama Chicken             1  Agra
# 627        3400021  Chokho Jeeman Marwari Jain Bhojanalya             1  Agra
# 628        3400017                         Pinch Of Spice             1  Agra
#
#                                                Address     Locality  \
# 624  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 625  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 626        Main Market, Sadar Bazaar, Agra Cantt, Agra   Agra Cantt
# 627  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...  Civil Lines
# 628  23/453, Opposite Sanjay Cinema, Wazipura Road,...  Civil Lines
#
#       Locality Verbose  Longitude   Latitude                        Cuisines  \
# ...

# %%
final_df.shape
# Out:
# (8652, 22)

# %% [markdown]
# ### which city is densly surrounded by zameto restaruants.

# %%
k=final_df["City"].value_counts().reset_index()
k
# Out:
#            index  City
# 0      New Delhi  5473
# 1        Gurgaon  1118
# 2          Noida  1080
# 3      Faridabad   251
# 4      Ghaziabad    25
# 5      Ahmedabad    21
# 6       Guwahati    21
# 7        Lucknow    21
# 8   Bhubaneshwar    21
# 9       Amritsar    21
# 10          Pune    20
# 11    Puducherry    20
# 12         Patna    20
# 13      Ludhiana    20
# 14        Ranchi    20
# 15         Surat    20
# 16      Vadodara    20
# 17        Nashik    20
# 18        Nagpur    20
# 19        Mysore    20
# 20        Mumbai    20
# 21      Varanasi    20
# 22     Mangalore    20
# 23          Agra    20
# 24         Kochi    20
# 25       Kolkata    20
# 26      Dehradun    20
# 27     Allahabad    20
# 28    Aurangabad    20
# 29     Bangalore    20
# 30        Bhopal    20
# 31       Chennai    20
# 32    Coimbatore    20
# 33           Goa    20
# 34        Indore    20
# 35        Jaipur    20
# 36        Kanpur    20
# 37         Vizag    20
# 38    Chandigarh    18
# ...

# %%
sns.countplot(x="City",data=final_df)
plt.xticks(rotation=90);

# %%
plt.pie(x=k["City"],labels=k["index"],autopct="%0.01f%%")
plt.legend();

# %%
k["index"].iloc[5:43]=k["index"].iloc[5:43].apply(lambda x:"others")
k
# Out:
# C:\Users\ad\AppData\Local\Temp\ipykernel_2260\4174955765.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k["index"].iloc[5:43]=k["index"].iloc[5:43].apply(lambda x:"others")
#         index  City
# 0   New Delhi  5473
# 1     Gurgaon  1118
# 2       Noida  1080
# 3   Faridabad   251
# 4   Ghaziabad    25
# 5      others    21
# 6      others    21
# 7      others    21
# 8      others    21
# 9      others    21
# 10     others    20
# 11     others    20
# 12     others    20
# 13     others    20
# 14     others    20
# 15     others    20
# 16     others    20
# 17     others    20
# 18     others    20
# 19     others    20
# 20     others    20
# 21     others    20
# 22     others    20
# 23     others    20
# 24     others    20
# 25     others    20
# 26     others    20
# ...

# %%
k1=k.groupby(["index"])["City"].sum().reset_index()
k1
# Out:
#        index  City
# 0  Faridabad   251
# 1  Ghaziabad    25
# 2    Gurgaon  1118
# 3  New Delhi  5473
# 4      Noida  1080
# 5     others   705

# %%
plt.pie(k1["City"],explode=[1,2,0,0,0,0],labels=k1["index"],autopct="%0.04f%%");

# %% [markdown]
# ## statistical summary

# %%
final_df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   8.652000e+03        8652.0  8652.000000  8652.000000
# mean    8.657085e+06           1.0    72.856786    26.420652
# std     8.959437e+06           0.0    18.017536     6.976576
# min     5.300000e+01           1.0     0.000000     0.000000
# 25%     3.007402e+05           1.0    77.098797    28.491425
# 50%     2.200006e+06           1.0    77.203468    28.569869
# 75%     1.836120e+07           1.0    77.285356    28.637857
# max     1.850065e+07           1.0    91.806493    35.000000
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           8652.000000  8652.000000       8652.000000   8652.000000
# mean             623.370319     1.721683          2.523324    137.212552
# std              595.676124     0.852544          1.510986    428.039513
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
Cuisines=final_df["Cuisines"].value_counts().reset_index()
Cuisines
# Out:
#                                                   index  Cuisines
# 0                                          North Indian       936
# 1                                 North Indian, Chinese       511
# 2                                             Fast Food       348
# 3                                               Chinese       340
# 4                                 North Indian, Mughlai       334
# ...                                                 ...       ...
# 1387  Chinese, Japanese, Thai, Malaysian, Vietnamese...         1
# 1388                 North Indian, Street Food, Mughlai         1
# 1389    Seafood, South Indian, Andhra, Hyderabadi, Goan         1
# 1390     Chinese, Fast Food, North Indian, South Indian         1
# 1391          American, North Indian, Thai, Continental         1
#
# [1392 rows x 2 columns]

# %% [markdown]
# ### which restraurant is expensive based on cuisines type of each city

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
z=final_df[final_df["Average Cost for two"]!=0]
z.head(3)
# Out:
#      Restaurant ID          Restaurant Name  Country Code  City  \
# 624        3400025               Jahanpanah             1  Agra
# 625        3400341      Rangrezz Restaurant             1  Agra
# 626        3400005  Time2Eat - Mama Chicken             1  Agra
#
#                                                Address    Locality  \
# 624  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...  Agra Cantt
# 625  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...  Agra Cantt
# 626        Main Market, Sadar Bazaar, Agra Cantt, Agra  Agra Cantt
#
#      Locality Verbose  Longitude   Latitude               Cuisines  ...  \
# 624  Agra Cantt, Agra  78.011544  27.161661  North Indian, Mughlai  ...
# 625  Agra Cantt, Agra   0.000000   0.000000  North Indian, Mughlai  ...
# 626  Agra Cantt, Agra  78.011608  27.160832           North Indian  ...
#
#      Has Table booking Has Online delivery Is delivering now  \
# 624                 No                  No                No
# ...

# %% [markdown]
# ## which my hot selling cuisines.

# %%
cuisines=final_df["Cuisines"].value_counts().reset_index()
cuisines
# Out:
#                                                   index  Cuisines
# 0                                          North Indian       936
# 1                                 North Indian, Chinese       511
# 2                                             Fast Food       348
# 3                                               Chinese       340
# 4                                 North Indian, Mughlai       334
# ...                                                 ...       ...
# 1387  Chinese, Japanese, Thai, Malaysian, Vietnamese...         1
# 1388                 North Indian, Street Food, Mughlai         1
# 1389    Seafood, South Indian, Andhra, Hyderabadi, Goan         1
# 1390     Chinese, Fast Food, North Indian, South Indian         1
# 1391          American, North Indian, Thai, Continental         1
#
# [1392 rows x 2 columns]

# %%
final_df["Cuisines"].unique()
# Out:
# array(['North Indian, Mughlai', 'North Indian', 'Rajasthani', ...,
#        'Continental, Seafood, Chinese, North Indian, Biryani',
#        'Burger, Pizza, Biryani',
#        'American, North Indian, Thai, Continental'], dtype=object)

# %% [markdown]
# ### which restaruant is expensive based on cuisine type of each city.

# %%
final_df["Average Cost for two"].unique()
# Out:
# array([ 850,  700,  500,  400, 1000, 2000, 2500,  800, 3600,    0,  550,
#        1100, 1500,  900, 1800,  300, 1400,  350,  450,  600,  950, 1200,
#         200,  100,  150,  650, 1300, 2400,  250, 1600, 2200,  750, 1700,
#        1250, 1900, 2700, 3500, 5000, 2300, 1750, 3200, 3000, 2100, 1850,
#        4500, 4000, 3300,  120, 1350, 1650, 1950, 1050,  290,   50, 1450,
#        2800,  260, 3650, 4800, 1550,  720, 6500, 7000, 1150, 2900, 2600,
#        4700, 3700, 3800, 4100, 4300, 2650, 6000, 5100, 5500, 4400, 4200,
#        8000, 2350], dtype=int64)

# %%
f=final_df[final_df["Average Cost for two"]!=0]
f
# Out:
#       Restaurant ID                        Restaurant Name  Country Code  \
# 624         3400025                             Jahanpanah             1
# 625         3400341                    Rangrezz Restaurant             1
# 626         3400005                Time2Eat - Mama Chicken             1
# 627         3400021  Chokho Jeeman Marwari Jain Bhojanalya             1
# 628         3400017                         Pinch Of Spice             1
# ...             ...                                    ...           ...
# 9271        2800100                               D Cabana             1
# 9272        2800418                               Kaloreez             1
# 9273        2800881                                Plot 17             1
# 9274        2800042                       Vista - The Park             1
# 9275        2800019               Flying Spaghetti Monster             1
#
#        City                                            Address  \
# ...

# %%
k=f.groupby(["City","Cuisines"])["Average Cost for two"].mean().reset_index().sort_values(by=["City","Average Cost for two"])

# %%
k
# Out:
#        City                                           Cuisines  \
# 10     Agra                                         Rajasthani
# 3      Agra                                       North Indian
# 12     Agra                             South Indian, Desserts
# 1      Agra                                     Italian, Pizza
# 8      Agra                            North Indian, Fast Food
# ...     ...                                                ...
# 2203  Vizag  Chinese, Thai, Burmese, Vietnamese, Tibetan, J...
# 2207  Vizag                                            Italian
# 2196  Vizag          American, North Indian, Thai, Continental
# 2210  Vizag               North Indian, Chinese, Mediterranean
# 2204  Vizag                          Continental, North Indian
#
#       Average Cost for two
# 10                   400.0
# 3                    500.0
# 12                   550.0
# 1                    700.0
# 8                    700.0
# ...                    ...
# ...

# %% [markdown]
# ## for agra only

# %%
# how many restraurant of each cuisine in each city.

# %% [markdown]
# ## which cuisines type restro has highest and lowest rating in each city

# %%
k1=k.groupby(["City","Cuisines"])["Average Cost for two"].agg(["mean"]).reset_index().sort_values(by=["City","mean"])
k1.head(13)
# Out:
#     City                                     Cuisines    mean
# 10  Agra                                   Rajasthani   400.0
# 3   Agra                                 North Indian   500.0
# 12  Agra                       South Indian, Desserts   550.0
# 1   Agra                               Italian, Pizza   700.0
# 8   Agra                      North Indian, Fast Food   700.0
# 11  Agra                Rajasthani, Gujarati, Mughlai   800.0
# 0   Agra  Chinese, Italian, Continental, North Indian  1000.0
# 6   Agra               North Indian, Chinese, Mughlai  1000.0
# 5   Agra  North Indian, Chinese, Continental, Mughlai  1100.0
# 4   Agra           North Indian, Chinese, Continental  1500.0
# 9   Agra                        North Indian, Mughlai  1710.0
# 7   Agra                       North Indian, European  2000.0
# 2   Agra                                      Mughlai  2500.0

# %% [markdown]
# ## how many restaurant of each cuisine in each city.

# %%
k=f.groupby(["City"])["Cuisines"].value_counts()
k
# Out:
# City   Cuisines
# Agra   North Indian, Mughlai                                        5
#        Chinese, Italian, Continental, North Indian                  1
#        Italian, Pizza                                               1
#        Mughlai                                                      1
#        North Indian                                                 1
#                                                                    ..
# Vizag  Mughlai, Chinese, Cafe, BBQ, Cajun                           1
#        North Indian, Biryani                                        1
#        North Indian, Chinese, Mediterranean                         1
#        South Indian, Chinese, Continental, Italian, North Indian    1
#        South Indian, North Indian                                   1
# Name: Cuisines, Length: 2214, dtype: int64

# %% [markdown]
# ## which cuisines type restro has highest and lowest rating in each city

# %%
k1=f.groupby(["City","Cuisines"])["Aggregate rating"].agg(["mean"]).reset_index().sort_values(by=["City","mean"])
k1.head(13)
# Out:
#     City                                     Cuisines  mean
# 5   Agra  North Indian, Chinese, Continental, Mughlai  3.40
# 3   Agra                                 North Indian  3.60
# 11  Agra                Rajasthani, Gujarati, Mughlai  3.60
# 4   Agra           North Indian, Chinese, Continental  3.80
# 9   Agra                        North Indian, Mughlai  3.84
# 2   Agra                                      Mughlai  4.00
# 7   Agra                       North Indian, European  4.00
# 10  Agra                                   Rajasthani  4.00
# 8   Agra                      North Indian, Fast Food  4.10
# 12  Agra                       South Indian, Desserts  4.10
# 0   Agra  Chinese, Italian, Continental, North Indian  4.20
# 6   Agra               North Indian, Chinese, Mughlai  4.20
# 1   Agra                               Italian, Pizza  4.40

# %% [markdown]
# ## Italian, Pizza type restaurant has tha good ratings 4.40

# %%
type(123) = int
 type(19/12/2022) = object
type(20-12-2022) = int
# Out:
#   Input In [43]
#     type(123) = int
#     ^
# SyntaxError: cannot assign to function call

# %%
type(19/12/2022)

# %%
type(20-12-2022)

# %%
type(123)

# %% [markdown]
# ### what is tha avg rating of tha restaurant in india.

# %%
final_df["Aggregate rating"].agg(["mean","max","min"])

# %%
ratings=final_df.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index().rename(columns={0:"Rating count"})
ratings

# %%
plt.figure(figsize=(10,5))
sns.barplot(ratings['Aggregate rating'],ratings['Rating count'],data=ratings);

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Aggregate rating', y='Rating count',hue="Rating color",data=ratings,palette=["white","red","orange","yellow","green","green"]);

# %% [markdown]
# ### Frequency distribution of rating color in data.

# %%
ratings["Rating color"].value_counts()

# %%
sns.countplot(ratings["Rating color"],data=ratings,palette=["blue","red","orange","yellow","green","green"]);

# %% [markdown]
# ### which restaurant are more rated in each city.

# %%
k=final_df.groupby(["City","Restaurant Name","Aggregate rating"])["Votes"].agg(["mean"]).reset_index()
k.rename(columns={"mean":"Votes"},inplace=True)

# %%
k.sort_values(by=["Aggregate rating","Votes"],ascending=False)

# %% [markdown]
# ## so we can find tha best restaurant in each city

# %% [markdown]
# ## find tha best restaurant in New Delhi.

# %%
k[k["City"]=="New Delhi"].sort_values(by="Aggregate rating",ascending=False)

# %% [markdown]
# ### Following details most rated restaurants in new delhi

# %%
final_df[(final_df["City"]=="New Delhi") & (final_df["Aggregate rating"]==4.9)][["Restaurant Name","Locality","Cuisines","Average Cost for two","Has Table booking","Average Cost for two","Votes","Has Online delivery","Rating color","Rating text"]]

# %% [markdown]
# ## how many resrtaurantwhich having rating 0.0

# %%
k1=final_df[final_df["Aggregate rating"]==0.0]
k1.groupby(["City"])["Rating text"].value_counts()
# Out:
# City       Rating text
# Faridabad  Not rated       100
# Ghaziabad  Not rated         2
# Gurgaon    Not rated       228
# New Delhi  Not rated      1425
# Noida      Not rated       384
# Name: Rating text, dtype: int64

# %% [markdown]
# ### most unrated restaurant is new delhi itself

# %% [markdown]
# ### how many restaurant give online me delivery and prior table booking to their costumers.

# %%
print("tha number of restaurant which gives a online delivery, prior table booking to their costumers----",len(final_df[(final_df["Has Online delivery"]=="Yes") & (final_df["Has Table booking"]=="Yes")]))
# Out:
# tha number of restaurant which gives a online delivery, prior table booking to their costumers---- 427

# %%
print("tha number of restaurant which gives a online delivery,  no prior table booking to their costumers----",len(final_df[(final_df["Has Online delivery"]=="Yes") & (final_df["Has Table booking"]=="No")]))
print("tha number of restaurant which gives only prior table booking not online bookings----",len(final_df[(final_df["Has Online delivery"]=="No") & (final_df["Has Table booking"]=="Yes")]))
print("tha number of restaurant  which give neither of options----",len(final_df[(final_df["Has Online delivery"]=="No") & (final_df["Has Table booking"]=="No")]))
# Out:
# tha number of restaurant which gives a online delivery,  no prior table booking to their costumers---- 1996
# tha number of restaurant which gives only prior table booking not online bookings---- 684
# tha number of restaurant  which give neither of options---- 5545

# %%
sns.relplot(x="Aggregate rating",y="Average Cost for two",data=final_df)

# %%
sns.relplot(x="Aggregate rating",y="Votes",data=final_df)

# %%
final_df.columns    #["Aggregate rating"].agg(["mean","max","min"])
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df2["Country"].value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
country_names=df2["Country"].value_counts().index
country_names
# Out:
# Index(['India', 'United States', 'United Kingdom', 'Brazil', 'UAE',
#        'South Africa', 'New Zealand', 'Turkey', 'Australia', 'Phillipines',
#        'Indonesia', 'Singapore', 'Qatar', 'Sri Lanka', 'Canada'],
#       dtype='object')

# %%
country_val=df2["Country"].value_counts().values
country_val
# Out:
# array([8652,  434,   80,   60,   60,   60,   40,   34,   24,   22,   21,
#          20,   20,   20,    4], dtype=int64)

# %%
### pie chart

plt.pie(country_val[0:3],labels=country_names[0:3],autopct="%1.2f%%");

# %% [markdown]
# ## insight
# ###  zometo maxm records and transaction are from india after that United state and united kingdom

# %%
ratings=df2.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index().rename(columns={0:"Rating count"})
ratings.head()
# Out:
#    Aggregate rating Rating color Rating text  Rating count
# 0               0.0        White   Not rated          2148
# 1               1.8          Red        Poor             1
# 2               1.9          Red        Poor             2
# 3               2.0          Red        Poor             7
# 4               2.1          Red        Poor            15

# %% [markdown]
# ## insights
# ##### 1:whn tha rating is btw 4.5 to 4.9 : Excellent
# ##### 2:whn tha rating is btw 3.5 to 4.0 : Very Good
# ##### 3:whn tha rating is btw 3.5 to 3.9 : Good
# ##### 4:whn tha rating is btw 3.0 to 3.4 : average
# ##### 5:whn tha rating is btw 2.5 to 2.9 : average
# ##### 6:whn tha rating is btw 1.8 to 2.4 : poor

# %%
plt.figure(figsize=(10,8))##plt.figuresize(figsize(10,5))
sns.barplot(x='Aggregate rating', y='Rating count',data=ratings);

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Aggregate rating', y='Rating count',hue="Rating color",data=ratings,palette=["white","red","orange","yellow","green","green"]);

# %%
sns.countplot(x="Rating color",data=ratings,palette=["blue","red","orange","yellow","green","green"]);

# %% [markdown]
# ### find country name which has zero ratings.

# %%
zero_rating=df2[df2["Aggregate rating"]==0]
zero_rating.head()
# Out:
#     Restaurant ID        Restaurant Name  Country Code            City  \
# 30        6600060         Sandubas Cafí©            30       Brasí_lia
# 58        7305048  Quiosque Chopp Brahma            30  Rio de Janeiro
# 69        6710645       Cantinho da Gula            30      Sí£o Paulo
# 77        6701419          Divino Fogí£o            30      Sí£o Paulo
# 78        6703956            Super Grill            30      Sí£o Paulo
#
#                                               Address  \
# 30  Edifí_cio Josí© Severo, SCS 6, Bloco A, Loja 9...
# 58  Madureira Shopping - Loja 289/290, Piso 2, Est...
# 69  Rua Pedroso Alvarenga, 522, Itaim Bibi, Sí£o P...
# 77  Shopping MetríÇ Santa Cruz - Piso L2, Rua Domi...
# 78  Shopping Morumbi - Piso Lazer, Avenida Roque P...
#
#                                     Locality  \
# 30                                   Asa Sul
# 58                                 Madureira
# 69                                Itaim Bibi
# ...

# %%
zero_rating.groupby(["Country"]).size() #.reset_index()
# Out:
# Country
# Brazil               5
# India             2139
# United Kingdom       1
# United States        3
# dtype: int64

# %% [markdown]
# ###  insight
# ##### maxm 0 reating from indian costumers

# %% [markdown]
# ### find out which currency is used by which country?

# %%
df2.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df2.groupby(["Country"])["Currency"].value_counts()
# Out:
# Country         Currency
# Australia       Dollar($)                   24
# Brazil          Brazilian Real(R$)          60
# Canada          Dollar($)                    4
# India           Indian Rupees(Rs.)        8652
# Indonesia       Indonesian Rupiah(IDR)      21
# New Zealand     NewZealand($)               40
# Phillipines     Botswana Pula(P)            22
# Qatar           Qatari Rial(QR)             20
# Singapore       Dollar($)                   20
# South Africa    Rand(R)                     60
# Sri Lanka       Sri Lankan Rupee(LKR)       20
# Turkey          Turkish Lira(TL)            34
# UAE             Emirati Diram(AED)          60
# United Kingdom  Pounds(Œ£)                  80
# United States   Dollar($)                  434
# Name: Currency, dtype: int64

# %% [markdown]
# ### which country has onlline dilvery?

# %%
df2[df2["Has Online delivery"] == "Yes"].Country.value_counts()
# Out:
# India    2423
# UAE        28
# Name: Country, dtype: int64

# %%
df2.groupby(["Country","Has Online delivery"]).size().reset_index().rename(columns={0:"online dervery count"})
# Out:
#            Country Has Online delivery  online dervery count
# 0        Australia                  No                    24
# 1           Brazil                  No                    60
# 2           Canada                  No                     4
# 3            India                  No                  6229
# 4            India                 Yes                  2423
# 5        Indonesia                  No                    21
# 6      New Zealand                  No                    40
# 7      Phillipines                  No                    22
# 8            Qatar                  No                    20
# 9        Singapore                  No                    20
# 10    South Africa                  No                    60
# 11       Sri Lanka                  No                    20
# 12          Turkey                  No                    34
# 13             UAE                  No                    32
# ...

# %% [markdown]
# ### online delveries are available in INDIA and YAE.

# %% [markdown]
# ### check tha pie chart for  top 5 cities distribution?

# %%
df2.City.value_counts().index
# Out:
# Index(['New Delhi', 'Gurgaon', 'Noida', 'Faridabad', 'Ghaziabad',
#        'Bhubaneshwar', 'Amritsar', 'Ahmedabad', 'Lucknow', 'Guwahati',
#        ...
#        'Ojo Caliente', 'Montville', 'Monroe', 'Miller', 'Middleton Beach',
#        'Panchkula', 'Mc Millan', 'Mayfield', 'Macedon', 'Vineland Station'],
#       dtype='object', length=141)

# %%
city_labels=df2["City"].value_counts().index
city_labels
#city_val=df2["City"].value_counts().values
#city_val
# Out:
# Index(['New Delhi', 'Gurgaon', 'Noida', 'Faridabad', 'Ghaziabad',
#        'Bhubaneshwar', 'Amritsar', 'Ahmedabad', 'Lucknow', 'Guwahati',
#        ...
#        'Ojo Caliente', 'Montville', 'Monroe', 'Miller', 'Middleton Beach',
#        'Panchkula', 'Mc Millan', 'Mayfield', 'Macedon', 'Vineland Station'],
#       dtype='object', length=141)

# %%
plt.figure(figsize=(30,5))
plt.pie(city_val[0:5],labels=city_names[0:5],autopct="%1.2f%%");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [67], in <cell line: 2>()
#       1 plt.figure(figsize=(30,5))
# ----> 2 plt.pie(city_val[0:5],labels=city_names[0:5],autopct="%1.2f%%")
#
# NameError: name 'city_val' is not defined

# %% [markdown]
# ##  find top 10 cuisine.

# %%
df2["Cuisines"].value_counts()

# %%
cus_values = df2["Cuisines"].value_counts().values
print(cus_values) 



cus_labels = df2["Cuisines"].value_counts().index
print(cus_labels)
# Out:
# [945 511 354 ...   1   1   1]
# Index(['North Indian', 'North Indian, Chinese', 'Chinese', 'Fast Food',
#        'North Indian, Mughlai', 'Cafe', 'Bakery',
#        'North Indian, Mughlai, Chinese', 'Bakery, Desserts', 'Street Food',
#        ...
#        'Cafe, Pizza, Burger',
#        'Healthy Food, Continental, Juices, Beverages, Italian, Salad, Lebanese',
#        'Goan, American, Portuguese', 'South Indian, Desserts, Beverages',
#        'Healthy Food, North Indian, Italian, Salad', 'Bengali, Fast Food',
#        'North Indian, Rajasthani, Asian',
#        'Chinese, Thai, Malaysian, Indonesian',
#        'Bakery, Desserts, North Indian, Bengali, South Indian',
#        'Italian, World Cuisine'],
#       dtype='object', length=1825)

# %%
plt.figure(figsize=(30,5))
plt.pie(cus_values[:10],labels=cus_labels[:10],autopct='%1.2f%%');#(With respect to Aggregate rating)

# %%
df2.groupby(['Aggregate rating'])['Cuisines'].size().reset_index().tail(10)
# Out:
#     Aggregate rating  Cuisines
# 23               4.0       266
# 24               4.1       274
# 25               4.2       221
# 26               4.3       174
# 27               4.4       144
# 28               4.5        95
# 29               4.6        78
# 30               4.7        42
# 31               4.8        25
# 32               4.9        61
