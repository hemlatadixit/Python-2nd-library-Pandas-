# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### data reading

# %%
df=pd.read_csv("C:\\Users\\ad\\Downloads\\pokemon.csv")
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ### checking rows and columns.

# %%
df.shape
# Out:
# (800, 12)

# %%
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %% [markdown]
# ### columns names

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ### checking datatypes of data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      359 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %% [markdown]
# ### to see missing values %

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# #              0.000
# Name           0.000
# Type 1         0.000
# Type 2        55.125
# HP             0.000
# Attack         0.000
# Defense        0.000
# Sp. Atk        0.000
# Sp. Def        0.000
# Speed          0.000
# Generation     0.000
# Legendary      0.000
# dtype: float64

# %% [markdown]
# ###  To deleting tha irrelavent columns.

# %%
df.drop(columns=["Type 2","#"],inplace=True)

# %%
df
# Out:
#                       Name   Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0                Bulbasaur    Grass  45      49       49       65       65
# 1                  Ivysaur    Grass  60      62       63       80       80
# 2                 Venusaur    Grass  80      82       83      100      100
# 3    VenusaurMega Venusaur    Grass  80     100      123      122      120
# 4               Charmander     Fire  39      52       43       60       50
# ..                     ...      ...  ..     ...      ...      ...      ...
# 795                Diancie     Rock  50     100      150      100      150
# 796    DiancieMega Diancie     Rock  50     160      110      160      110
# 797    HoopaHoopa Confined  Psychic  80     110       60      150      130
# 798     HoopaHoopa Unbound  Psychic  80     160       60      170      130
# 799              Volcanion     Fire  80     110      120      130       90
#
#      Speed  Generation  Legendary
# ...

# %%
df.describe()   ### to check statistical
# Out:
#                HP      Attack     Defense     Sp. Atk     Sp. Def       Speed  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean    69.258750   79.001250   73.842500   72.820000   71.902500   68.277500
# std     25.534669   32.457366   31.183501   32.722294   27.828916   29.060474
# min      1.000000    5.000000    5.000000   10.000000   20.000000    5.000000
# 25%     50.000000   55.000000   50.000000   49.750000   50.000000   45.000000
# 50%     65.000000   75.000000   70.000000   65.000000   70.000000   65.000000
# 75%     80.000000  100.000000   90.000000   95.000000   90.000000   90.000000
# max    255.000000  190.000000  230.000000  194.000000  230.000000  180.000000
#
#        Generation
# count   800.00000
# mean      3.32375
# std       1.66129
# min       1.00000
# 25%       2.00000
# 50%       3.00000
# 75%       5.00000
# max       6.00000

# %%
df["Name"]
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df.describe().T
# Out:
#             count      mean        std   min    25%   50%    75%    max
# HP          800.0  69.25875  25.534669   1.0  50.00  65.0   80.0  255.0
# Attack      800.0  79.00125  32.457366   5.0  55.00  75.0  100.0  190.0
# Defense     800.0  73.84250  31.183501   5.0  50.00  70.0   90.0  230.0
# Sp. Atk     800.0  72.82000  32.722294  10.0  49.75  65.0   95.0  194.0
# Sp. Def     800.0  71.90250  27.828916  20.0  50.00  70.0   90.0  230.0
# Speed       800.0  68.27750  29.060474   5.0  45.00  65.0   90.0  180.0
# Generation  800.0   3.32375   1.661290   1.0   2.00   3.0    5.0    6.0

# %%
df.describe(include=object).T
# Out:
#        count unique        top freq
# Name     800    800  Bulbasaur    1
# Type 1   800     18      Water  112

# %% [markdown]
# ### To read multiple columns

# %%
### FETCH THA SPACIFIC COLUMN AND LAGENDARY.
df[["Name","Type 1","HP"]]
# Out:
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]

# %% [markdown]
# ## WE NEED TO SOME ROWS 30 TO 50

# %%
df.iloc[30:50]
# Out:
#                 Name    Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 30           Pikachu  Electric   35      55       40       50       50     90
# 31            Raichu  Electric   60      90       55       90       80    110
# 32         Sandshrew    Ground   50      75       85       20       30     40
# 33         Sandslash    Ground   75     100      110       45       55     65
# 34  Nidoran (Female)    Poison   55      47       52       40       40     41
# 35          Nidorina    Poison   70      62       67       55       55     56
# 36         Nidoqueen    Poison   90      92       87       75       85     76
# 37    Nidoran (Male)    Poison   46      57       40       40       40     50
# 38          Nidorino    Poison   61      72       57       55       55     65
# 39          Nidoking    Poison   81     102       77       85       75     85
# 40          Clefairy     Fairy   70      45       48       60       65     35
# ...

# %%
df[["Name","HP"]][400:411]
# Out:
#                         Name   HP
# 400                  Walrein  110
# 401                 Clamperl   35
# 402                  Huntail   55
# 403                 Gorebyss   55
# 404                Relicanth  100
# 405                  Luvdisc   43
# 406                    Bagon   45
# 407                  Shelgon   65
# 408                Salamence   95
# 409  SalamenceMega Salamence   95
# 410                   Beldum   40

# %% [markdown]
# ### to read multiple columns of certain rows

# %%
df.iloc[3]  ##to deleting particular row
# Out:
# Name          VenusaurMega Venusaur
# Type 1                        Grass
# HP                               80
# Attack                          100
# Defense                         123
# Sp. Atk                         122
# Sp. Def                         120
# Speed                            80
# Generation                        1
# Legendary                     False
# Name: 3, dtype: object

# %%
df.iloc[10:16,2:7]
# Out:
#     HP  Attack  Defense  Sp. Atk  Sp. Def
# 10  59      63       80       65       80
# 11  79      83      100       85      105
# 12  79     103      120      135      115
# 13  45      30       35       20       20
# 14  50      20       55       25       25
# 15  60      45       50       90       80

# %%
df.iloc[11,0]
# Out:
# 'Blastoise'

# %%
df.iloc[11,0][0]
# Out:
# 'B'

# %% [markdown]
# ### to iterate tha reach roww on specific column

# %%
for i in df["Name"]:
    print(i)
# Out:
# Bulbasaur
# Ivysaur
# Venusaur
# VenusaurMega Venusaur
# Charmander
# Charmeleon
# Charizard
# CharizardMega Charizard X
# CharizardMega Charizard Y
# Squirtle
# Wartortle
# Blastoise
# BlastoiseMega Blastoise
# Caterpie
# Metapod
# Butterfree
# Weedle
# Kakuna
# Beedrill
# BeedrillMega Beedrill
# Pidgey
# Pidgeotto
# Pidgeot
# PidgeotMega Pidgeot
# Rattata
# Raticate
# Spearow
# Fearow
# Ekans
# Arbok
# Pikachu
# Raichu
# Sandshrew
# Sandslash
# Nidoran (Female)
# Nidorina
# Nidoqueen
# Nidoran (Male)
# Nidorino
# Nidoking
# Clefairy
# Clefable
# Vulpix
# Ninetales
# Jigglypuff
# Wigglytuff
# Zubat
# Golbat
# Oddish
# Gloom
# Vileplume
# Paras
# Parasect
# Venonat
# Venomoth
# Diglett
# Dugtrio
# Meowth
# Persian
# Psyduck
# Golduck
# Mankey
# Primeape
# Growlithe
# Arcanine
# Poliwag
# Poliwhirl
# Poliwrath
# Abra
# Kadabra
# Alakazam
# AlakazamMega Alakazam
# Machop
# Machoke
# Machamp
# Bellsprout
# Weepinbell
# Victreebel
# Tentacool
# Tentacruel
# Geodude
# Graveler
# Golem
# ...

# %% [markdown]
# ### to iterate multiple rows.

# %%
for i,j in df.iterrows():
    print(i,"-------------",j)
# Out:
# 0 ------------- Name          Bulbasaur
# Type 1            Grass
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object
# 1 ------------- Name          Ivysaur
# Type 1          Grass
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object
# 2 ------------- Name          Venusaur
# Type 1           Grass
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 2, dtype: object
# 3 ------------- Name          VenusaurMega Venusaur
# Type 1                        Grass
# ...

# %% [markdown]
# ### to find unique values of eacg columns

# %%
for i in df.columns:
    print(i,"unique values---------",df[i].unique())
# Out:
# Name unique values--------- ['Bulbasaur' 'Ivysaur' 'Venusaur' 'VenusaurMega Venusaur' 'Charmander'
#  'Charmeleon' 'Charizard' 'CharizardMega Charizard X'
#  'CharizardMega Charizard Y' 'Squirtle' 'Wartortle' 'Blastoise'
#  'BlastoiseMega Blastoise' 'Caterpie' 'Metapod' 'Butterfree' 'Weedle'
#  'Kakuna' 'Beedrill' 'BeedrillMega Beedrill' 'Pidgey' 'Pidgeotto'
#  'Pidgeot' 'PidgeotMega Pidgeot' 'Rattata' 'Raticate' 'Spearow' 'Fearow'
#  'Ekans' 'Arbok' 'Pikachu' 'Raichu' 'Sandshrew' 'Sandslash'
#  'Nidoran (Female)' 'Nidorina' 'Nidoqueen' 'Nidoran (Male)' 'Nidorino'
#  'Nidoking' 'Clefairy' 'Clefable' 'Vulpix' 'Ninetales' 'Jigglypuff'
#  'Wigglytuff' 'Zubat' 'Golbat' 'Oddish' 'Gloom' 'Vileplume' 'Paras'
#  'Parasect' 'Venonat' 'Venomoth' 'Diglett' 'Dugtrio' 'Meowth' 'Persian'
#  'Psyduck' 'Golduck' 'Mankey' 'Primeape' 'Growlithe' 'Arcanine' 'Poliwag'
#  'Poliwhirl' 'Poliwrath' 'Abra' 'Kadabra' 'Alakazam'
#  'AlakazamMega Alakazam' 'Machop' 'Machoke' 'Machamp' 'Bellsprout'
# ...

# %% [markdown]
# ### how many types of pokemon in dataset

# %%
(df["Type 1"].unique())
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
len(df["Type 1"].unique())   ### total
# Out:
# 18

# %%
df["Type 1"].nunique()   ### total
# Out:
# 18

# %% [markdown]
# ## which pokemon type comes maximum time in tha data.

# %%
df["Type 1"].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
df["Type 1"].mode()
# Out:
# 0    Water
# Name: Type 1, dtype: object

# %% [markdown]
# #### fetch  pokemon name whose hit points is maximum

# %%
df[df["HP"]==df["HP"].max()]
# Out:
#         Name  Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 261  Blissey  Normal  255      10       10       75      135     55
#
#      Generation  Legendary
# 261           2      False

# %%
df[df["HP"]==df["HP"].max()]["Name"]
# Out:
# 261    Blissey
# Name: Name, dtype: object

# %%
### feature engineering
df["Total"]=df.iloc[:,2:8].sum(axis=1)
df
# Out:
#                       Name   Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0                Bulbasaur    Grass  45      49       49       65       65
# 1                  Ivysaur    Grass  60      62       63       80       80
# 2                 Venusaur    Grass  80      82       83      100      100
# 3    VenusaurMega Venusaur    Grass  80     100      123      122      120
# 4               Charmander     Fire  39      52       43       60       50
# ..                     ...      ...  ..     ...      ...      ...      ...
# 795                Diancie     Rock  50     100      150      100      150
# 796    DiancieMega Diancie     Rock  50     160      110      160      110
# 797    HoopaHoopa Confined  Psychic  80     110       60      150      130
# 798     HoopaHoopa Unbound  Psychic  80     160       60      170      130
# 799              Volcanion     Fire  80     110      120      130       90
#
#      Speed  Generation  Legendary  Total
# ...

# %%
df["Legendary"]=df["Legendary"].astype(np.int)
df
# Out:
# C:\Users\ad\AppData\Local\Temp\ipykernel_9784\4270032598.py:1: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df["Legendary"]=df["Legendary"].astype(np.int)
#                       Name   Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0                Bulbasaur    Grass  45      49       49       65       65
# 1                  Ivysaur    Grass  60      62       63       80       80
# 2                 Venusaur    Grass  80      82       83      100      100
# 3    VenusaurMega Venusaur    Grass  80     100      123      122      120
# ...

# %% [markdown]
# ### 1: who is tha strong pokemonand weakest.

# %%
df["Total"].max()
# Out:
# 780

# %% [markdown]
# ### 2: find out tha chrac of pikachu pokemon.

# %%
df[df["Name"]=="Pikachu"]
# Out:
#        Name    Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 30  Pikachu  Electric  35      55       40       50       50     90
#
#     Generation  Legendary  Total
# 30           1          0    320

# %% [markdown]
# ### 3: how lengends pokemon.

# %%
df["Legendary"].unique()
# Out:
# array([0, 1])

# %%
df["Legendary"].value_counts()
# Out:
# 0    735
# 1     65
# Name: Legendary, dtype: int64

# %% [markdown]
# ### 4: upto which generationn pokemon exits.

# %%
df["Generation"].value_counts()
# Out:
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: Generation, dtype: int64

# %% [markdown]
# ### 5: which category of pkemon stronfesr anf weakest.

# %%
df[df["Total"]==df["Total"].max()]["Type 1"]
# Out:
# 163    Psychic
# 164    Psychic
# 426     Dragon
# Name: Type 1, dtype: object

# %%
df[df["Total"]==df["Total"].min()]["Type 1"]
# Out:
# 206    Grass
# Name: Type 1, dtype: object

# %%
df.drop_duplicates(subset=['Type 1'],keep='first')
# Out:
#                         Name    Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0                  Bulbasaur     Grass  45      49       49       65       65
# 4                 Charmander      Fire  39      52       43       60       50
# 9                   Squirtle     Water  44      48       65       50       64
# 13                  Caterpie       Bug  45      30       35       20       20
# 20                    Pidgey    Normal  40      45       40       35       35
# 28                     Ekans    Poison  35      60       44       40       54
# 30                   Pikachu  Electric  35      55       40       50       50
# 32                 Sandshrew    Ground  50      75       85       20       30
# 40                  Clefairy     Fairy  70      45       48       60       65
# 61                    Mankey  Fighting  40      80       35       35       45
# 68                      Abra   Psychic  25      20       15      105       55
# ...

# %% [markdown]
# ### 6: find top 5  strongst pokemon  based on total.

# %%
df.sort_values(by="Total",ascending=False).head()
# Out:
#                       Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 426  RayquazaMega Rayquaza   Dragon  105     180      100      180      100
# 164    MewtwoMega Mewtwo Y  Psychic  106     150       70      194      120
# 163    MewtwoMega Mewtwo X  Psychic  106     190      100      154      100
# 422    KyogrePrimal Kyogre    Water  100     150       90      180      160
# 424  GroudonPrimal Groudon   Ground  100     180      160      150       90
#
#      Speed  Generation  Legendary  Total
# 426    115           3          1    780
# 164    140           1          1    780
# 163    130           1          1    780
# 422     90           3          1    770
# 424     90           3          1    770

# %% [markdown]
# ### 7: find max mean min and average state of each category(type ) of pokemon

# %%
df.groupby("Type 1")["Total"].agg(["max","min","mean"])
# Out:
#           max  min        mean
# Type 1
# Bug       600  194  378.927536
# Dark      680  220  445.741935
# Dragon    780  300  550.531250
# Electric  610  205  443.409091
# Fairy     680  218  413.176471
# Fighting  625  210  416.444444
# Fire      680  250  458.076923
# Flying    580  245  485.000000
# Ghost     680  275  439.562500
# Grass     630  180  421.142857
# Ground    770  265  437.500000
# Ice       580  250  433.458333
# Normal    720  190  401.683673
# Poison    535  245  399.142857
# Psychic   780  198  475.947368
# Rock      700  280  453.750000
# Steel     700  300  487.703704
# Water     770  200  430.455357

# %% [markdown]
# ### 8: which  pokemon  whose points is max  and min.

# %%
df[df["Total"]==df["Total"].max()]
# Out:
#                       Name   Type 1   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 163    MewtwoMega Mewtwo X  Psychic  106     190      100      154      100
# 164    MewtwoMega Mewtwo Y  Psychic  106     150       70      194      120
# 426  RayquazaMega Rayquaza   Dragon  105     180      100      180      100
#
#      Speed  Generation  Legendary  Total
# 163    130           1          1    780
# 164    140           1          1    780
# 426    115           3          1    780

# %%
df[df["Total"]==df["Total"].min()]
# Out:
#         Name Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# 206  Sunkern  Grass  30      30       30       30       30     30           2
#
#      Legendary  Total
# 206          0    180

# %% [markdown]
# ### 9: find avg, max,min, nad total starts type

# %%
df.groupby(["Type 1","Name"])["Total"].agg(["max","min","mean"])
# Out:
#                               max  min   mean
# Type 1 Name
# Bug    Accelgor               495  495  495.0
#        Ariados                390  390  390.0
#        Beautifly              395  395  395.0
#        Beedrill               395  395  395.0
#        BeedrillMega Beedrill  495  495  495.0
# ...                           ...  ...    ...
# Water  Wailord                500  500  500.0
#        Wartortle              405  405  405.0
#        Whiscash               468  468  468.0
#        Wingull                270  270  270.0
#        Wooper                 210  210  210.0
#
# [800 rows x 3 columns]

# %% [markdown]
# ### 10: which genatrion pokemon is strong

# %%
df.groupby(["Generation"])["Total"].agg(["mean","max","min"]).sort_values(by="max",ascending=False)
# Out:
#                   mean  max  min
# Generation
# 1           426.813253  780  195
# 3           436.225000  780  190
# 4           459.016529  720  194
# 2           418.283019  700  180
# 5           434.987879  700  255
# 6           436.378049  700  200
